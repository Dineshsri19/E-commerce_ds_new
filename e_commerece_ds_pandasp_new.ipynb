# %%
import pandas as pd

# %%
df=pd.read_csv("e-comm_trans_ds.zip")

# %%
df
# Out:
#        Transaction_ID           User_Name  Age    Country Product_Category  \
# 0                   1            Ava Hall   63     Mexico         Clothing
# 1                   2         Sophia Hall   59      India           Beauty
# 2                   3     Elijah Thompson   26     France            Books
# 3                   4        Elijah White   43     Mexico           Sports
# 4                   5          Ava Harris   48    Germany           Beauty
# ...               ...                 ...  ...        ...              ...
# 49995           49996  Isabella Rodriguez   53      India      Electronics
# 49996           49997           Emma Hall   30     France   Home & Kitchen
# 49997           49998      Isabella Allen   50  Australia           Beauty
# 49998           49999        Olivia Clark   48  Australia          Grocery
# 49999           50000       Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
df.tail()
# Out:
#        Transaction_ID           User_Name  Age    Country Product_Category  \
# 49995           49996  Isabella Rodriguez   53      India      Electronics
# 49996           49997           Emma Hall   30     France   Home & Kitchen
# 49997           49998      Isabella Allen   50  Australia           Beauty
# 49998           49999        Olivia Clark   48  Australia          Grocery
# 49999           50000       Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# 49995           140.09               UPI       2024-08-07
# 49996           815.31  Cash on Delivery       2025-02-07
# 49997           535.77               UPI       2023-08-11
# 49998           370.99  Cash on Delivery       2025-01-02
# 49999           577.66       Credit Card       2024-06-03

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.describe()
# Out:
#        Transaction_ID           Age  Purchase_Amount
# count    50000.000000  50000.000000     50000.000000
# mean     25000.500000     43.968680       503.159793
# std      14433.901067     15.260578       286.563558
# min          1.000000     18.000000         5.040000
# 25%      12500.750000     31.000000       255.450000
# 50%      25000.500000     44.000000       503.110000
# 75%      37500.250000     57.000000       751.162500
# max      50000.000000     70.000000       999.980000

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'User_Name', 'Age', 'Country', 'Product_Category',
#        'Purchase_Amount', 'Payment_Method', 'Transaction_Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    50000 non-null  int64
#  1   User_Name         50000 non-null  object
#  2   Age               50000 non-null  int64
#  3   Country           50000 non-null  object
#  4   Product_Category  50000 non-null  object
#  5   Purchase_Amount   50000 non-null  float64
#  6   Payment_Method    50000 non-null  object
#  7   Transaction_Date  50000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.1+ MB

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# User_Name           0
# Age                 0
# Country             0
# Product_Category    0
# Purchase_Amount     0
# Payment_Method      0
# Transaction_Date    0
# dtype: int64

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
df.Product_Category.unique()
# Out:
# array(['Clothing', 'Beauty', 'Books', 'Sports', 'Toys', 'Home & Kitchen',
#        'Grocery', 'Electronics'], dtype=object)

# %%
df.Payment_Method.unique()
# Out:
# array(['Debit Card', 'PayPal', 'Credit Card', 'UPI', 'Net Banking',
#        'Cash on Delivery'], dtype=object)

# %%
df.Payment_Method.unique()
# Out:
# array(['Debit Card', 'PayPal', 'Credit Card', 'UPI', 'Net Banking',
#        'Cash on Delivery'], dtype=object)

# %%
df.groupby("Country")["Payment_Method"].sum()
# Out:
# Country
# Australia    Net BankingDebit CardPayPalUPICash on Delivery...
# Brazil       UPIPayPalCredit CardCash on DeliveryCash on De...
# Canada       Debit CardCash on DeliveryCash on DeliveryDebi...
# France       Credit CardCash on DeliveryPayPalNet BankingDe...
# Germany      Net BankingCredit CardCash on DeliveryDebit Ca...
# India        PayPalCash on DeliveryCash on DeliveryPayPalCa...
# Japan        Net BankingUPICash on DeliveryPayPalCash on De...
# Mexico       Debit CardUPIPayPalUPIPayPalCredit CardDebit C...
# UK           PayPalCredit CardPayPalDebit CardNet BankingCr...
# USA          PayPalUPINet BankingUPICredit CardCash on Deli...
# Name: Payment_Method, dtype: object

# %%
df.groupby("Country")["Purchase_Amount"].sum()
# Out:
# Country
# Australia    2514911.65
# Brazil       2507287.54
# Canada       2544335.12
# France       2545739.19
# Germany      2502442.20
# India        2503542.71
# Japan        2492312.20
# Mexico       2534475.67
# UK           2471723.15
# USA          2541220.22
# Name: Purchase_Amount, dtype: float64

# %%
df.groupby("Country")["Purchase_Amount"].sum().idxmax()
# Out:
# 'France'

# %%
df.groupby("Country")["Purchase_Amount"].sum().idxmin()
# Out:
# 'UK'

# %%
df.groupby(["Country","Product_Category"])["Purchase_Amount"].agg({"sum","max","min"})
# Out:
#                                   sum    min     max
# Country   Product_Category
# Australia Beauty            322842.39   5.23  999.17
#           Books             299037.66   6.53  997.74
#           Clothing          310470.99   7.65  999.95
#           Electronics       316239.62  11.60  994.99
#           Grocery           335303.16   5.68  999.89
# ...                               ...    ...     ...
# USA       Electronics       313828.14   5.24  998.94
#           Grocery           325796.08   6.69  997.71
#           Home & Kitchen    328129.75   5.87  997.74
#           Sports            315109.47   5.16  998.47
#           Toys              322012.33   5.13  999.32
#
# [80 rows x 3 columns]

# %%
df["Product_Category"].value_counts()
# Out:
# Product_Category
# Toys              6392
# Electronics       6320
# Sports            6312
# Books             6253
# Clothing          6224
# Grocery           6215
# Home & Kitchen    6209
# Beauty            6075
# Name: count, dtype: int64

# %%
df["Transaction_Date"]=pd.to_datetime(df["Transaction_Date"])

# %%
df["Year"]=df["Transaction_Date"].dt.year

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year
# 0           780.69     Debit Card       2023-04-14  2023
# 1           738.56         PayPal       2023-07-30  2023
# 2           178.34    Credit Card       2023-09-17  2023
# 3           401.09            UPI       2023-06-21  2023
# 4           594.83    Net Banking       2024-10-29  2024

# %%
df["Month"]=df["Transaction_Date"].dt.month

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year  Month
# 0           780.69     Debit Card       2023-04-14  2023      4
# 1           738.56         PayPal       2023-07-30  2023      7
# 2           178.34    Credit Card       2023-09-17  2023      9
# 3           401.09            UPI       2023-06-21  2023      6
# 4           594.83    Net Banking       2024-10-29  2024     10

# %%
df["Month"]=df["Transaction_Date"].dt.month_name()

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month
# 0           780.69     Debit Card       2023-04-14  2023      April
# 1           738.56         PayPal       2023-07-30  2023       July
# 2           178.34    Credit Card       2023-09-17  2023  September
# 3           401.09            UPI       2023-06-21  2023       June
# 4           594.83    Net Banking       2024-10-29  2024    October

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month
# 0           780.69     Debit Card       2023-04-14  2023      April
# 1           738.56         PayPal       2023-07-30  2023       July
# 2           178.34    Credit Card       2023-09-17  2023  September
# 3           401.09            UPI       2023-06-21  2023       June
# 4           594.83    Net Banking       2024-10-29  2024    October

# %%
df["Days"]=df["Transaction_Date"].dt.day

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month  Days
# 0           780.69     Debit Card       2023-04-14  2023      April    14
# 1           738.56         PayPal       2023-07-30  2023       July    30
# 2           178.34    Credit Card       2023-09-17  2023  September    17
# 3           401.09            UPI       2023-06-21  2023       June    21
# 4           594.83    Net Banking       2024-10-29  2024    October    29

# %%
df["Days"]=df["Transaction_Date"].dt.day_name()

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month       Days
# 0           780.69     Debit Card       2023-04-14  2023      April     Friday
# 1           738.56         PayPal       2023-07-30  2023       July     Sunday
# 2           178.34    Credit Card       2023-09-17  2023  September     Sunday
# 3           401.09            UPI       2023-06-21  2023       June  Wednesday
# 4           594.83    Net Banking       2024-10-29  2024    October    Tuesday

# %%
df["Weekday"]=df["Transaction_Date"].dt.weekday

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month  \
# 0           780.69     Debit Card       2023-04-14  2023      April
# 1           738.56         PayPal       2023-07-30  2023       July
# 2           178.34    Credit Card       2023-09-17  2023  September
# 3           401.09            UPI       2023-06-21  2023       June
# 4           594.83    Net Banking       2024-10-29  2024    October
#
#         Days  Weekday
# 0     Friday        4
# 1     Sunday        6
# 2     Sunday        6
# 3  Wednesday        2
# 4    Tuesday        1

# %%
df["Weekend"]=df["Weekday"].apply(lambda x: "weekend" if x >= 5 else "weekday")

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month  \
# 0           780.69     Debit Card       2023-04-14  2023      April
# 1           738.56         PayPal       2023-07-30  2023       July
# 2           178.34    Credit Card       2023-09-17  2023  September
# 3           401.09            UPI       2023-06-21  2023       June
# 4           594.83    Net Banking       2024-10-29  2024    October
#
#         Days  Weekday  Weekend
# 0     Friday        4  weekday
# 1     Sunday        6  weekend
# 2     Sunday        6  weekend
# ...

# %%
df.set_index("Transaction_ID")
# Out:
#                          User_Name  Age    Country Product_Category  \
# Transaction_ID
# 1                         Ava Hall   63     Mexico         Clothing
# 2                      Sophia Hall   59      India           Beauty
# 3                  Elijah Thompson   26     France            Books
# 4                     Elijah White   43     Mexico           Sports
# 5                       Ava Harris   48    Germany           Beauty
# ...                            ...  ...        ...              ...
# 49996           Isabella Rodriguez   53      India      Electronics
# 49997                    Emma Hall   30     France   Home & Kitchen
# 49998               Isabella Allen   50  Australia           Beauty
# 49999                 Olivia Clark   48  Australia          Grocery
# 50000                Olivia Harris   70     Canada           Sports
#
#                 Purchase_Amount    Payment_Method Transaction_Date  Year  \
# Transaction_ID
# ...

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date  Year      Month  \
# 0           780.69     Debit Card       2023-04-14  2023      April
# 1           738.56         PayPal       2023-07-30  2023       July
# 2           178.34    Credit Card       2023-09-17  2023  September
# 3           401.09            UPI       2023-06-21  2023       June
# 4           594.83    Net Banking       2024-10-29  2024    October
#
#         Days  Weekday  Weekend
# 0     Friday        4  weekday
# 1     Sunday        6  weekend
# 2     Sunday        6  weekend
# ...

# %%
df.set_index("Transaction_ID",inplace=True)

# %%
df.head()
# Out:
#                       User_Name  Age  Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63   Mexico         Clothing
# 2                   Sophia Hall   59    India           Beauty
# 3               Elijah Thompson   26   France            Books
# 4                  Elijah White   43   Mexico           Sports
# 5                    Ava Harris   48  Germany           Beauty
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
# 4                        401.09            UPI       2023-06-21  2023
# 5                        594.83    Net Banking       2024-10-29  2024
#
#                     Month       Days  Weekday  Weekend
# Transaction_ID
# 1                   April     Friday        4  weekday
# ...

# %%
df.sort_index()
# Out:
#                          User_Name  Age    Country Product_Category  \
# Transaction_ID
# 1                         Ava Hall   63     Mexico         Clothing
# 2                      Sophia Hall   59      India           Beauty
# 3                  Elijah Thompson   26     France            Books
# 4                     Elijah White   43     Mexico           Sports
# 5                       Ava Harris   48    Germany           Beauty
# ...                            ...  ...        ...              ...
# 49996           Isabella Rodriguez   53      India      Electronics
# 49997                    Emma Hall   30     France   Home & Kitchen
# 49998               Isabella Allen   50  Australia           Beauty
# 49999                 Olivia Clark   48  Australia          Grocery
# 50000                Olivia Harris   70     Canada           Sports
#
#                 Purchase_Amount    Payment_Method Transaction_Date  Year  \
# Transaction_ID
# ...

# %%
df.head()
# Out:
#                       User_Name  Age  Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63   Mexico         Clothing
# 2                   Sophia Hall   59    India           Beauty
# 3               Elijah Thompson   26   France            Books
# 4                  Elijah White   43   Mexico           Sports
# 5                    Ava Harris   48  Germany           Beauty
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
# 4                        401.09            UPI       2023-06-21  2023
# 5                        594.83    Net Banking       2024-10-29  2024
#
#                     Month       Days  Weekday  Weekend
# Transaction_ID
# 1                   April     Friday        4  weekday
# ...

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                       User_Name  Age  Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63   Mexico         Clothing
# 2                   Sophia Hall   59    India           Beauty
# 3               Elijah Thompson   26   France            Books
# 4                  Elijah White   43   Mexico           Sports
# 5                    Ava Harris   48  Germany           Beauty
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
# 4                        401.09            UPI       2023-06-21  2023
# 5                        594.83    Net Banking       2024-10-29  2024
#
#                     Month       Days  Weekday  Weekend
# Transaction_ID
# 1                   April     Friday        4  weekday
# ...

# %%
df.loc[0:23]
# Out:
#                       User_Name  Age    Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63     Mexico         Clothing
# 2                   Sophia Hall   59      India           Beauty
# 3               Elijah Thompson   26     France            Books
# 4                  Elijah White   43     Mexico           Sports
# 5                    Ava Harris   48    Germany           Beauty
# 6                 Elijah Harris   51      India             Toys
# 7                  Oliver Clark   27    Germany   Home & Kitchen
# 8                  Olivia Allen   46     Canada   Home & Kitchen
# 9                   Liam Harris   54     France           Beauty
# 10                   Liam Allen   60     Canada           Beauty
# 11                  James Clark   30      Japan   Home & Kitchen
# 12                 Sophia Allen   48      Japan          Grocery
# 13                Sophia Harris   21     France             Toys
# ...

# %%
df.loc[0:4,"User_Name":"Payment_Method"]
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63  Mexico         Clothing
# 2                   Sophia Hall   59   India           Beauty
# 3               Elijah Thompson   26  France            Books
# 4                  Elijah White   43  Mexico           Sports
#
#                 Purchase_Amount Payment_Method
# Transaction_ID
# 1                        780.69     Debit Card
# 2                        738.56         PayPal
# 3                        178.34    Credit Card
# 4                        401.09            UPI

# %%
df.loc[0:4,["User_Name","Age","Purchase_Amount"]]
# Out:
#                       User_Name  Age  Purchase_Amount
# Transaction_ID
# 1                      Ava Hall   63           780.69
# 2                   Sophia Hall   59           738.56
# 3               Elijah Thompson   26           178.34
# 4                  Elijah White   43           401.09

# %%
df.head(3)
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63  Mexico         Clothing
# 2                   Sophia Hall   59   India           Beauty
# 3               Elijah Thompson   26  France            Books
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
#
#                     Month    Days  Weekday  Weekend
# Transaction_ID
# 1                   April  Friday        4  weekday
# 2                    July  Sunday        6  weekend
# 3               September  Sunday        6  weekend

# %%
df.iloc[0:4]
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63  Mexico         Clothing
# 2                   Sophia Hall   59   India           Beauty
# 3               Elijah Thompson   26  France            Books
# 4                  Elijah White   43  Mexico           Sports
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
# 4                        401.09            UPI       2023-06-21  2023
#
#                     Month       Days  Weekday  Weekend
# Transaction_ID
# 1                   April     Friday        4  weekday
# 2                    July     Sunday        6  weekend
# 3               September     Sunday        6  weekend
# ...

# %%
df.iloc[0:4,1:3]
# Out:
#                 Age Country
# Transaction_ID
# 1                63  Mexico
# 2                59   India
# 3                26  France
# 4                43  Mexico

# %%
df.iloc[0:4,[1,3,7]]
# Out:
#                 Age Product_Category  Year
# Transaction_ID
# 1                63         Clothing  2023
# 2                59           Beauty  2023
# 3                26            Books  2023
# 4                43           Sports  2023

# %%
df.head(3)
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63  Mexico         Clothing
# 2                   Sophia Hall   59   India           Beauty
# 3               Elijah Thompson   26  France            Books
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
#
#                     Month    Days  Weekday  Weekend
# Transaction_ID
# 1                   April  Friday        4  weekday
# 2                    July  Sunday        6  weekend
# 3               September  Sunday        6  weekend

# %%
df.loc[(df["Country"]=="India") & (df["Product_Category"]) & (df["Purchase_Amount"] > 500)]
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 2                   Sophia Hall   59   India           Beauty
# 6                 Elijah Harris   51   India             Toys
# 20               James Thompson   43   India             Toys
# 54                   Noah White   32   India           Sports
# 65                Sophia Walker   53   India             Toys
# ...                         ...  ...     ...              ...
# 49838              Sophia Allen   41   India         Clothing
# 49854           Sophia Thompson   18   India          Grocery
# 49898              Olivia Clark   36   India            Books
# 49902             Emma Anderson   35   India            Books
# 49952                 Ava Clark   68   India      Electronics
#
#                 Purchase_Amount    Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 2                        738.56            PayPal       2023-07-30  2023
# ...

# %%
df.loc[(df["Country"]=="France") & (df["Product_Category"]=="Beauty") & (df["Purchase_Amount"] >= 300) & (df["Payment_Method"]=="UPI")]
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 90                 Sophia Allen   69  France           Beauty
# 315             Oliver Thompson   24  France           Beauty
# 1262              Emma Thompson   54  France           Beauty
# 2835               Sophia White   58  France           Beauty
# 3400               Sophia Lewis   27  France           Beauty
# ...                         ...  ...     ...              ...
# 46849             Sophia Walker   44  France           Beauty
# 47925                 Ava Allen   20  France           Beauty
# 48693              Olivia Lewis   26  France           Beauty
# 49748              Sophia White   47  France           Beauty
# 49883             Oliver Walker   59  France           Beauty
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 90                       353.67            UPI       2024-11-09  2024
# ...

# %%
df.head(3)
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63  Mexico         Clothing
# 2                   Sophia Hall   59   India           Beauty
# 3               Elijah Thompson   26  France            Books
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
#
#                     Month    Days  Weekday  Weekend
# Transaction_ID
# 1                   April  Friday        4  weekday
# 2                    July  Sunday        6  weekend
# 3               September  Sunday        6  weekend

# %%
df.Year.unique()
# Out:
# array([2023, 2024, 2025])

# %%
df.groupby("Year")["Purchase_Amount"].sum()
# Out:
# Year
# 2023    10226819.03
# 2024    12640798.03
# 2025     2290372.59
# Name: Purchase_Amount, dtype: float64

# %%
df.groupby("Country")["Purchase_Amount"].sum()
# Out:
# Country
# Australia    2514911.65
# Brazil       2507287.54
# Canada       2544335.12
# France       2545739.19
# Germany      2502442.20
# India        2503542.71
# Japan        2492312.20
# Mexico       2534475.67
# UK           2471723.15
# USA          2541220.22
# Name: Purchase_Amount, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(26,8))
sns.barplot(x="Country", y="Purchase_Amount", data=df)
plt.xlabel("Country")
plt.ylabel("Purchase_Amount")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,3))
sns.barplot(x="Country", y="Purchase_Amount",color = "Green", data=df, estimator = sum)
plt.xlabel("Country")
plt.ylabel("Purchase_Amount")
plt.show()

# %%
df.groupby("Year")["Purchase_Amount"].sum()
# Out:
# Year
# 2023    10226819.03
# 2024    12640798.03
# 2025     2290372.59
# Name: Purchase_Amount, dtype: float64

# %%
df_rd=df.groupby("Year")["Purchase_Amount"].sum()
plt.figure(figsize=(10,3))
unique_rd=df_rd.index
df_rd.plot(kind="line", marker="o", color = "Green", linestyle="--")
plt.xticks(unique_rd)
plt.show()

# %%
df.head(3)
# Out:
#                       User_Name  Age Country Product_Category  \
# Transaction_ID
# 1                      Ava Hall   63  Mexico         Clothing
# 2                   Sophia Hall   59   India           Beauty
# 3               Elijah Thompson   26  France            Books
#
#                 Purchase_Amount Payment_Method Transaction_Date  Year  \
# Transaction_ID
# 1                        780.69     Debit Card       2023-04-14  2023
# 2                        738.56         PayPal       2023-07-30  2023
# 3                        178.34    Credit Card       2023-09-17  2023
#
#                     Month    Days  Weekday  Weekend
# Transaction_ID
# 1                   April  Friday        4  weekday
# 2                    July  Sunday        6  weekend
# 3               September  Sunday        6  weekend

# %%
df.groupby("Product_Category")["Purchase_Amount"].sum()
# Out:
# Product_Category
# Beauty            3057387.79
# Books             3181897.30
# Clothing          3171225.96
# Electronics       3133965.04
# Grocery           3123579.52
# Home & Kitchen    3108945.78
# Sports            3195335.90
# Toys              3185652.36
# Name: Purchase_Amount, dtype: float64

# %%
df_dfet=df.groupby("Product_Category")["Purchase_Amount"].sum()
plt.figure(figsize=(10,10))
df_dfet.plot(kind="pie", labels=df_dfet.index, autopct= "%1.1f%%")
plt.show()

# %%
df_fd=df.groupby("Year")["Purchase_Amount"].sum()
plt.figure(figsize=(8,10))
df_fd.plot(kind="pie", labels=df_fd.index, autopct = "%1.1f%%")
plt.xlabel("YEAR")
plt.show()

# %%
                                                    Thank You...!
